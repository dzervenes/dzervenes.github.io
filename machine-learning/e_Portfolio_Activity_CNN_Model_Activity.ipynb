# %% [markdown]
# <a href="https://colab.research.google.com/github/dzervenes/dzervenes.github.io/blob/master/e_Portfolio_Activity_CNN_Model_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Convolutional Neural Networks (CNN) - Object Recognition**
#
# In this notebook, I will explore and evaluate a Convolutional Neural Network (CNN) model for object recognition. By running the model and modifying the input image index, I aim to analyse the model's prediction accuracy across different test cases. This process will allow me to review key sections of the algorithm, document my observations, and reflect on the model's performance and potential limitations.

# %% [markdown]
# ##**Code**
#
# This section dynamically executes code from the external notebook Unit09 Ex1 Convolutional Neural Networks (CNN) - Object Recognition.ipynb. Using the nbformat library, the notebook is parsed, and all code cells are executed in the current Colab environment. This method loads the external notebook's functions, variables, and models efficiently, allowing for experimentation in separate cells without modifying the original file.

# %%
import nbformat

# Path to your notebook file
notebook_path = "/content/drive/MyDrive/Unit09 Ex1 Convolutional Neural Networks (CNN) - Object Recognition.ipynb"

# Read and parse the notebook
with open(notebook_path) as f:
    notebook = nbformat.read(f, as_version=4)

# Extract and run code cells
for cell in notebook['cells']:
    if cell['cell_type'] == 'code':
        code = cell['source']
        # Skip lines with magic commands
        if code.startswith('%'):
            print(f"Skipped magic command: {code.strip()}")
            continue
        try:
            exec(code)
        except Exception as e:
            print(f"Error executing code: {code}\n{e}")
# Out:
# Error executing code: import os
# import numpy as np
# import itertools
#
# import tensorflow as tf
# import keras
# from keras.datasets import cifar10 # importing the dataset
#
# from keras.models import Sequential       #to define model/ layers
# from keras.layers import Dense, Conv2D, MaxPool2D, Flatten
#
# from sklearn.metrics import confusion_matrix
#
# # To Explore the images
# from IPython.display import display
# from keras.preprocessing.image import array_to_img
#
# from tensorflow.keras.utils import to_categorical
#
# import matplotlib.pyplot as plt
# %matplotlib inline
# invalid syntax (<string>, line 21)
# <PIL.Image.Image image mode=RGB size=32x32>
# Number of images = 50000 	| width = 32 	| height = 32 	| channels = 3
# ...

# %% [markdown]
# **Experimenting with model predictions**
#
# In this section, I test the CNN model by selecting an image from the dataset using the specified index. The image is displayed, and its true label is retrieved. The model processes the image to generate predicted probabilities for each class, from which the predicted class is determined. Finally, the true label and the model's predicted class are compared to evaluate the model's accuracy for this specific input.

# %%
index = 2

plt.imshow(x_test[index])

my_image = x_test[index]

predicted_probabilities = model.predict(my_image.reshape(1, 32, 32, 3))

predicted_class = np.argmax(predicted_probabilities)

true_label = LABEL_NAMES[y_test[index][0]]
print(f"True Label: {true_label}")
print(f"Predicted Class: {LABEL_NAMES[predicted_class]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# True Label: ship
# Predicted Class: ship

# %% [markdown]
# **Model prediction output**
#
# The model correctly identified the image as a "ship." The true label of the image was also "ship," confirming the accuracy of the model's prediction for this particular instance. This demonstrates the model's ability to classify objects accurately under the given conditions. Further experimentation with different input images will help evaluate the consistency and reliability of the model's performance.

# %%
index = 7

plt.imshow(x_test[index])

my_image = x_test[index]

predicted_probabilities = model.predict(my_image.reshape(1, 32, 32, 3))

predicted_class = np.argmax(predicted_probabilities)

true_label = LABEL_NAMES[y_test[index][0]]
print(f"True Label: {true_label}")
print(f"Predicted Class: {LABEL_NAMES[predicted_class]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True Label: frog
# Predicted Class: frog

# %% [markdown]
# **Model prediction output**
#
# The model's prediction of "frog" for this image matches the true label, indicating that it effectively recognises this category. This result reflects the model's capacity to process visual features accurately.

# %%
index = 12

plt.imshow(x_test[index])

my_image = x_test[index]

predicted_probabilities = model.predict(my_image.reshape(1, 32, 32, 3))

predicted_class = np.argmax(predicted_probabilities)

true_label = LABEL_NAMES[y_test[index][0]]
print(f"True Label: {true_label}")
print(f"Predicted Class: {LABEL_NAMES[predicted_class]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# True Label: dog
# Predicted Class: frog

# %% [markdown]
# **Model prediction output**
#
# The model misclassified the image, predicting it as a "frog" while the true label was "dog." This discrepancy highlights a potential limitation in the model's ability to differentiate between these classes. Investigating such errors further can shed light on specific weaknesses in the model's training or architecture, offering opportunities to refine and improve its performance.

# %% [markdown]
# **Summary**
#
# The model demonstrated its ability to correctly classify images in certain cases, such as identifying a "ship" and a "frog," reflecting its capacity to process visual features accurately under given conditions. However, it also showed limitations, as seen in the misclassification of a "dog" as a "frog." This error underscores potential challenges in distinguishing between similar classes. While the model's accurate predictions highlight its strengths, analysing instances of misclassification is crucial for identifying weaknesses and guiding improvements to enhance its overall performance and reliability.
